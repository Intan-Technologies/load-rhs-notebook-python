# %% [markdown]
# # Load Data from an Intan RHS file.
# ### Header information (and saved data, if present) will be stored in the *result* variable. You'll also be able to specify a channel's name to plot its recorded data as an example of accessing data from *result*.

# %%
# Load the background Python functions that allow for data loading and plotting
# %run importrhsutilities.py

# %% [markdown]
# ### Name of file to load. To load a different file, move it to the same directory as this notebook, and change the following 'filename' variable to point the name of your file.

# %%
#filename = 'sampledata.rhs' # Change this variable to load a different data file
filename = 'comp_rhx.rhs'
result, data_present = load_file(filename)
# Out:
# Reading Intan Technologies RHS2000 Data File, Version 3.0
#
# Found 32 amplifier channels.
# Found 2 board ADC channels.
# Found 2 board DAC channels.
# Found 2 board digital input channels.
# Found 2 board digital output channels.
#
# 26624 bytes per data block
# File contains 5.658 seconds of data.  Amplifiers were sampled at 30.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# 100% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 0.4 seconds

# %% [markdown]
# ### Once a file is loaded, all of its information is stored in the *result* variable. If further analysis of recorded data is desired, this is the variable that should be used.
#
# ### As an example, the plot_channel function (code in *importintanutilitiespy*) accesses *result* to plot a specific channel.

# %%
print_all_channel_names(result) # Uncomment this line and re-run cell to display names of all available channels
# Out:
# A-000
# A-001
# A-002
# A-003
# A-004
# A-005
# A-006
# A-007
# A-008
# A-009
# A-010
# A-011
# A-012
# A-013
# A-014
# A-015
# A-016
# A-017
# A-018
# A-019
# A-020
# A-021
# A-022
# A-023
# A-024
# A-025
# A-026
# A-027
# A-028
# A-029
# A-030
# A-031
# DC_A-000
# DC_A-001
# DC_A-002
# DC_A-003
# DC_A-004
# DC_A-005
# DC_A-006
# DC_A-007
# DC_A-008
# DC_A-009
# DC_A-010
# DC_A-011
# DC_A-012
# DC_A-013
# DC_A-014
# DC_A-015
# DC_A-016
# DC_A-017
# DC_A-018
# DC_A-019
# DC_A-020
# DC_A-021
# DC_A-022
# DC_A-023
# DC_A-024
# DC_A-025
# DC_A-026
# DC_A-027
# DC_A-028
# DC_A-029
# DC_A-030
# DC_A-031
# STIM_A-000
# STIM_A-001
# STIM_A-002
# STIM_A-003
# STIM_A-004
# STIM_A-005
# STIM_A-006
# STIM_A-007
# STIM_A-008
# STIM_A-009
# STIM_A-010
# STIM_A-011
# STIM_A-012
# STIM_A-013
# STIM_A-014
# STIM_A-015
# STIM_A-016
# STIM_A-017
# STIM_A-018
# STIM_A-019
# STIM_A-020
# STIM_A-021
# STIM_A-022
# STIM_A-023
# STIM_A-024
# STIM_A-025
# STIM_A-026
# STIM_A-027
# STIM_A-028
# STIM_A-029
# STIM_A-030
# STIM_A-031
# AMP_SETTLE_A-000
# AMP_SETTLE_A-001
# AMP_SETTLE_A-002
# AMP_SETTLE_A-003
# AMP_SETTLE_A-004
# AMP_SETTLE_A-005
# AMP_SETTLE_A-006
# AMP_SETTLE_A-007
# AMP_SETTLE_A-008
# AMP_SETTLE_A-009
# AMP_SETTLE_A-010
# AMP_SETTLE_A-011
# AMP_SETTLE_A-012
# AMP_SETTLE_A-013
# AMP_SETTLE_A-014
# AMP_SETTLE_A-015
# AMP_SETTLE_A-016
# AMP_SETTLE_A-017
# AMP_SETTLE_A-018
# AMP_SETTLE_A-019
# AMP_SETTLE_A-020
# AMP_SETTLE_A-021
# AMP_SETTLE_A-022
# AMP_SETTLE_A-023
# AMP_SETTLE_A-024
# AMP_SETTLE_A-025
# AMP_SETTLE_A-026
# AMP_SETTLE_A-027
# AMP_SETTLE_A-028
# AMP_SETTLE_A-029
# AMP_SETTLE_A-030
# AMP_SETTLE_A-031
# CHARGE_RECOVERY_A-000
# CHARGE_RECOVERY_A-001
# CHARGE_RECOVERY_A-002
# CHARGE_RECOVERY_A-003
# CHARGE_RECOVERY_A-004
# CHARGE_RECOVERY_A-005
# CHARGE_RECOVERY_A-006
# CHARGE_RECOVERY_A-007
# CHARGE_RECOVERY_A-008
# CHARGE_RECOVERY_A-009
# CHARGE_RECOVERY_A-010
# CHARGE_RECOVERY_A-011
# CHARGE_RECOVERY_A-012
# CHARGE_RECOVERY_A-013
# CHARGE_RECOVERY_A-014
# CHARGE_RECOVERY_A-015
# CHARGE_RECOVERY_A-016
# CHARGE_RECOVERY_A-017
# CHARGE_RECOVERY_A-018
# CHARGE_RECOVERY_A-019
# CHARGE_RECOVERY_A-020
# CHARGE_RECOVERY_A-021
# CHARGE_RECOVERY_A-022
# CHARGE_RECOVERY_A-023
# CHARGE_RECOVERY_A-024
# CHARGE_RECOVERY_A-025
# CHARGE_RECOVERY_A-026
# CHARGE_RECOVERY_A-027
# CHARGE_RECOVERY_A-028
# CHARGE_RECOVERY_A-029
# CHARGE_RECOVERY_A-030
# CHARGE_RECOVERY_A-031
# COMPLIANCE_LIMIT_A-000
# COMPLIANCE_LIMIT_A-001
# COMPLIANCE_LIMIT_A-002
# COMPLIANCE_LIMIT_A-003
# COMPLIANCE_LIMIT_A-004
# COMPLIANCE_LIMIT_A-005
# COMPLIANCE_LIMIT_A-006
# COMPLIANCE_LIMIT_A-007
# COMPLIANCE_LIMIT_A-008
# COMPLIANCE_LIMIT_A-009
# COMPLIANCE_LIMIT_A-010
# COMPLIANCE_LIMIT_A-011
# COMPLIANCE_LIMIT_A-012
# COMPLIANCE_LIMIT_A-013
# COMPLIANCE_LIMIT_A-014
# COMPLIANCE_LIMIT_A-015
# COMPLIANCE_LIMIT_A-016
# COMPLIANCE_LIMIT_A-017
# COMPLIANCE_LIMIT_A-018
# COMPLIANCE_LIMIT_A-019
# COMPLIANCE_LIMIT_A-020
# COMPLIANCE_LIMIT_A-021
# COMPLIANCE_LIMIT_A-022
# COMPLIANCE_LIMIT_A-023
# COMPLIANCE_LIMIT_A-024
# COMPLIANCE_LIMIT_A-025
# COMPLIANCE_LIMIT_A-026
# COMPLIANCE_LIMIT_A-027
# COMPLIANCE_LIMIT_A-028
# COMPLIANCE_LIMIT_A-029
# COMPLIANCE_LIMIT_A-030
# COMPLIANCE_LIMIT_A-031
# ANALOG-IN-1
# ANALOG-IN-2
# ANALOG-OUT-1
# ANALOG-OUT-2
# DIGITAL-IN-01
# DIGITAL-IN-02
# DIGITAL-OUT-01
# DIGITAL-OUT-02

# %%
channel_name = 'DIGITAL-OUT-01' # Change this variable and re-run cell to plot a different channel

# %matplotlib inline

if data_present:
    plot_channel(channel_name, result)
    
else:
    print('Plotting not possible; no data in this file')
